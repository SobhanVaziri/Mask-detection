# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import models
import cv2
import os
import matplotlib.pyplot as plt
import numpy as np
import random
import pickle

# %%
img_array = cv2.imread("dataset\\no-mask\\0_0_chenxuedong_0050.jpg")
plt.imshow(img_array)

# %%
plt.imshow(cv2.cvtColor(img_array, cv2.COLOR_BGR2RGB))

# %%
img_array.shape
# Out:
# (146, 134, 3)

# %% [markdown]
# ## training data set:

# %%
dataset = "dataset\\"
Classes = ["no-mask", "mask"]
for category in Classes:
    path = os.path.join(dataset, category)
    for img in os.listdir(path):
        img_array = cv2.imread(os.path.join(path, img))
        plt.imshow(cv2.cvtColor(img_array, cv2.COLOR_BGR2RGB))
        plt.show()
        break
    break

# %%
img_size = 224
new_array = cv2.resize(img_array, (img_size, img_size))
plt.imshow(cv2.cvtColor(new_array, cv2.COLOR_BGR2RGB))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## training and save image on dataset:

# %%
training_data = []

def create_training_data():
    for category in Classes:
        path = os.path.join(dataset, category)
        class_num = Classes.index(category)
        for img in os.listdir(path):
            try:
                img_array = cv2.imread(os.path.join(path, img))
                new_array = cv2.resize(img_array, (img_size, img_size))
                training_data.append([new_array, class_num])
            except Exception as e:
                pass

# %%
create_training_data()

# %%
len(training_data)
# Out:
# 3810

# %%
random.shuffle(training_data)

# %%
x = []
y = []

for features, label in training_data:
    x.append(features)
    y.append(label)

x = np.array(x).reshape(-1, img_size, img_size, 3)


x.shape
# Out:
# (3810, 224, 224, 3)

# %%
x = x / 255.0

# %% [markdown]
# ## user have mask or no!?

# %%
y[1]
# Out:
# 1

# %%
y[1000]
# Out:
# 1

# %%
Y = np.array(y)

# %%
pickle_out = open("X.pickle", "wb")
pickle.dump(x, pickle_out)
pickle_out.close()

pickle_out = open("Y.pickle", "wb")
pickle.dump(y, pickle_out)
pickle_out.close()

# %%
pickle_in = open("X.pickle", "rb")
X = pickle.load(pickle_in)

pickle_in = open("Y.pickle", "rb")
Y = pickle.load(pickle_in)

# %% [markdown]
# ## deep learning for models:

# %%
new_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 new_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])
#
# NameError: name 'new_model' is not defined
